# %%
import pandas as pd

# %%
x = pd.read_csv('top_rated_movies.csv')
x
# Out:
#        Unnamed: 0  adult          genre_ids original_language  \
# 0               0  False  [28, 12, 16, 878]                en
# 1               1  False           [18, 80]                en
# 2               2  False           [18, 80]                en
# 3               3  False           [18, 80]                en
# 4               4  False    [35, 18, 10749]                hi
# ...           ...    ...                ...               ...
# 11155       11155  False               [37]                it
# 11156       11156  False       [12, 14, 28]                en
# 11157       11157  False   [28, 12, 16, 18]                en
# 11158       11158  False           [18, 80]                en
# 11159       11159  False        [18, 10749]                it
#
#                                                title  \
# 0                Spider-Man: Across the Spider-Verse
# 1                                      The Godfather
# 2                           The Shawshank Redemption
# ...

# %%
x.isnull().sum()
# Out:
# Unnamed: 0           0
# adult                0
# genre_ids            0
# original_language    0
# title                0
# overview             0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
mvnavidad = pd.read_csv('christmas_movies.csv')
mvnavidad.head()
# Out:
#                                    title rating  runtime  imdb_rating  \
# 0                          Love Actually      R    135.0          7.6
# 1  National Lampoon's Christmas Vacation  PG-13     97.0          7.5
# 2                               Spirited  PG-13    127.0          6.6
# 3                             Home Alone     PG    103.0          7.7
# 4         How the Grinch Stole Christmas     PG    104.0          6.3
#
#    meta_score                    genre  release_year  \
# 0        55.0   Comedy, Drama, Romance        2003.0
# 1        49.0                   Comedy        1989.0
# 2        55.0  Comedy, Family, Musical        2022.0
# 3        63.0           Comedy, Family        1990.0
# 4        46.0  Comedy, Family, Fantasy        2000.0
#
#                                          description             director  \
# 0  Follows the lives of eight very different coup...       Richard Curtis
# ...

# %%
mvnavidad.isnull().sum()
# Out:
# title             0
# rating          142
# runtime          39
# imdb_rating      39
# meta_score      692
# genre             1
# release_year      8
# description       0
# director          5
# stars            12
# votes            39
# gross           708
# img_src           0
# type              0
# dtype: int64

# %%
mvt = pd.read_csv('movies_updated.csv')
mvt
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 3995                                   Birthday Girl      R     Comedy  2001
# 3996                                    Human Nature      R     Comedy  2001
# 3997                                            Made      R     Comedy  2001
# 3998                           One Night at McCool's      R     Comedy  2001
# 3999                                  Dr. Dolittle 2     PG     Comedy  2001
#
# ...

# %%
mvt.isnull().sum()
# Out:
# name           0
# rating        40
# genre          0
# year           0
# released       0
# score          0
# votes          0
# director       0
# writer         1
# star           1
# country        0
# budget         0
# gross        169
# company       10
# runtime,,      0
# dtype: int64

# %%
imdb = pd.read_csv('imdb_raw.csv')
imdb
# Out:
#                         title              director release_year  runtime  \
# 0    The Shawshank Redemption        Frank Darabont       (1994)  142 min
# 1               The Godfather  Francis Ford Coppola       (1972)  175 min
# 2             The Dark Knight     Christopher Nolan       (2008)  152 min
# 3            Schindler's List      Steven Spielberg       (1993)  195 min
# 4                12 Angry Men          Sidney Lumet       (1957)   96 min
# ..                        ...                   ...          ...      ...
# 995    A Very Long Engagement    Jean-Pierre Jeunet       (2004)  133 min
# 996                     Shine           Scott Hicks       (1996)  105 min
# 997                 Philomena        Stephen Frears       (2013)   98 min
# 998         The Invisible Man           James Whale       (1933)   71 min
# 999                  Cell 211         Daniel Monzón       (2009)  113 min
#
#                          genre  rating  metascore     gross
# ...

# %%
imdb.isnull().sum()
# Out:
# title           0
# director        0
# release_year    0
# runtime         0
# genre           0
# rating          0
# metascore       0
# gross           0
# dtype: int64

# %%
df = pd.read_csv('mv.csv')
df
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# ...

# %%
df.isnull().sum()
# Out:
# rank                0
# release_date        1
# title               0
# url                 0
# production_cost     0
# domestic_gross      0
# worldwide_gross     0
# opening_weekend    21
# mpaa                8
# genre               5
# theaters           21
# runtime            13
# year                1
# dtype: int64

# %% [markdown]
# 1. https://www.kaggle.com/datasets/shabnamparveen/top-rated-movies
# 2. https://www.kaggle.com/datasets/jonbown/christmas-movies
# 3. https://www.kaggle.com/datasets/ashishkumarjayswal/movies-updated-data
# 4. https://www.kaggle.com/datasets/arthurchongg/imdb-top-1000-movies
# 5. https://www.kaggle.com/datasets/mitchellharrison/top-500-movies-budget
